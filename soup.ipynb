# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://api.github.com/search/users?q=type:org"
r = requests.get(url)
htmlcontent = r.content
print(htmlcontent)
# Out:
# b'{"total_count":3737898,"incomplete_results":false,"items":[{"login":"piLights","id":14963784,"node_id":"MDEyOk9yZ2FuaXphdGlvbjE0OTYzNzg0","avatar_url":"https://avatars.githubusercontent.com/u/14963784?v=4","gravatar_id":"","url":"https://api.github.com/users/piLights","html_url":"https://github.com/piLights","followers_url":"https://api.github.com/users/piLights/followers","following_url":"https://api.github.com/users/piLights/following{/other_user}","gists_url":"https://api.github.com/users/piLights/gists{/gist_id}","starred_url":"https://api.github.com/users/piLights/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/piLights/subscriptions","organizations_url":"https://api.github.com/users/piLights/orgs","repos_url":"https://api.github.com/users/piLights/repos","events_url":"https://api.github.com/users/piLights/events{/privacy}","received_events_url":"https://api.github.com/users/piLights/received_events","type":"Organization","site_admin":false,"score":1.
# ...

# %%
soup = BeautifulSoup(htmlcontent,'html.parser')

# %%
print(soup)
# Out:
# {"total_count":3737898,"incomplete_results":false,"items":[{"login":"piLights","id":14963784,"node_id":"MDEyOk9yZ2FuaXphdGlvbjE0OTYzNzg0","avatar_url":"https://avatars.githubusercontent.com/u/14963784?v=4","gravatar_id":"","url":"https://api.github.com/users/piLights","html_url":"https://github.com/piLights","followers_url":"https://api.github.com/users/piLights/followers","following_url":"https://api.github.com/users/piLights/following{/other_user}","gists_url":"https://api.github.com/users/piLights/gists{/gist_id}","starred_url":"https://api.github.com/users/piLights/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/piLights/subscriptions","organizations_url":"https://api.github.com/users/piLights/orgs","repos_url":"https://api.github.com/users/piLights/repos","events_url":"https://api.github.com/users/piLights/events{/privacy}","received_events_url":"https://api.github.com/users/piLights/received_events","type":"Organization","site_admin":false,"score":1.0}
# ...

# %%
print(soup.prettify())
# Out:
# {"total_count":3737898,"incomplete_results":false,"items":[{"login":"piLights","id":14963784,"node_id":"MDEyOk9yZ2FuaXphdGlvbjE0OTYzNzg0","avatar_url":"https://avatars.githubusercontent.com/u/14963784?v=4","gravatar_id":"","url":"https://api.github.com/users/piLights","html_url":"https://github.com/piLights","followers_url":"https://api.github.com/users/piLights/followers","following_url":"https://api.github.com/users/piLights/following{/other_user}","gists_url":"https://api.github.com/users/piLights/gists{/gist_id}","starred_url":"https://api.github.com/users/piLights/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/piLights/subscriptions","organizations_url":"https://api.github.com/users/piLights/orgs","repos_url":"https://api.github.com/users/piLights/repos","events_url":"https://api.github.com/users/piLights/events{/privacy}","received_events_url":"https://api.github.com/users/piLights/received_events","type":"Organization","site_admin":false,"score":1.0}
# ...

# %%
title = soup.title

# %%
print(title)
# Out:
# <title>Grocery Stores in Toronto ON | YellowPages.ca™</title>

# %%
print(type(title.string))
# Out:
# <class 'bs4.element.NavigableString'>

# %%
par = soup.find_all('a')
for i in par:
    print(i,end=" ")
# Out:
# <a data-analytics='{"lk_pos":"header","lk_se_id":"834ede2a-9214-473d-8b67-0706c28ab474_R3JvY2VyeSBTdG9yZXM_VG9yb250byBPTg","lk_area":"header","lk_name":"yplogo"}' data-qa="QAypLogoLhs" href="/" id="QAypLogoLhs" title="Yellowpages.ca Canadian Business Directory - Meet the New Neighbourhood"><img alt="Visit YP.ca to search for businesses in Canada" src="//static.yellowpages.ca/ypca/ypui-6.37.0.0-20210127.1352/resources/images/verticals/yellowpages/logo-en.svg"/></a> <a class="jsConnectButton" data-modal-url="/ajax/user/signin" data-qa="QAsignInLink" data-target="#jsModalContainer" data-toggle="ajax-modal">Log in</a> <a class="jsOtherLanguageUrl" data-analytics='{"lk_pos":"header","lk_se_id":"834ede2a-9214-473d-8b67-0706c28ab474_R3JvY2VyeSBTdG9yZXM_VG9yb250byBPTg","lk_area":"header","lk_name":"toggle_en"}' href="https://www.pagesjaunes.ca/search/si/1/Grocery+Stores/Toronto+ON?theme=shopwise" title="Visit Yellow Pages in French">
# ...

# %%
anchors = soup.find('a')
print(anchors)
# Out:
# <a data-analytics='{"lk_pos":"header","lk_se_id":"834ede2a-9214-473d-8b67-0706c28ab474_R3JvY2VyeSBTdG9yZXM_VG9yb250byBPTg","lk_area":"header","lk_name":"yplogo"}' data-qa="QAypLogoLhs" href="/" id="QAypLogoLhs" title="Yellowpages.ca Canadian Business Directory - Meet the New Neighbourhood"><img alt="Visit YP.ca to search for businesses in Canada" src="//static.yellowpages.ca/ypca/ypui-6.37.0.0-20210127.1352/resources/images/verticals/yellowpages/logo-en.svg"/></a>

# %%
print(soup.find_all("a", class_='mlr__item__cta'))
# Out:
# [<a class="mlr__item__cta jsMlrMenu" data-analytics-placeholder='{"lk_listing_id":"8165198","lk_non-ad-rollup":"0","lk_page_num":"1","lk_pos":"in_listing","lk_proximity":"10.8","lk_directory_heading":[{"109235":[{"00654100":"1"}]}],"lk_geo_tier":"in","lk_area":"left_1","lk_relevancy":"1","lk_name":"revealphonenumber","lk_pos_num":"1","lk_se_id":"834ede2a-9214-473d-8b67-0706c28ab474_R3JvY2VyeSBTdG9yZXM_VG9yb250byBPTg","lk_ev":"link","event_name":"click - Call - Reveal Phone Number","lk_product":"l1"}' data-phone="416-759-7680" href="javascript:void(0)" title="Get the Phone Number">
# ...

# %%
print(soup.find('p').get_text())
# Out:
# Were you looking for:

# %%
print(soup.get_text())
# Out:
# Grocery Stores in Toronto ON | YellowPages.ca™
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Please enter what you're searching for
#
#
#
#
#
#
# Please enter your search location
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
# Log in
#
#
# frPasser en français / Switch to French language
#
#
#
#
#
#
# Restaurants
# Dentists
# Medical Clinics
# Car Repair
# Grocery Stores
#
#
#
#
#
#
# ×
# Your account is now active!
#
#
#
#
#
#
#
#
#
# Grocery Stores in Toronto ON
# (2198 Result(s))
#
#
#
# Relevance
#
#
#
#
# Closest
#
#
# Highest rated
#
#
# Most reviewed
#
#
# Alphabetical
#
#
# Recently Reviewed
#
#
#
#
#
#
#
# Filters
#
#
#
#
#
#
#
#
#
#
#
#
# Shop Online
#
#
#
# Features
#
#
#
#
# Features
#
#
# Patio
#
#
# Wi-Fi
#
#
#
#
#
#
#
#
#
# Apply
#
# Clear
#
#
#
#
#
#
#
# Open now
#
#
# 24/7
#
#
# Neighbourhood
#
#
# ...

# %%
print(soup.find('a').get_text())

# %%
for link in soup.find_all('a'):
    if(link!='#'):
        print(link.get('href'))
# Out:
# /
# None
# https://www.pagesjaunes.ca/search/si/1/Grocery+Stores/Toronto+ON?theme=shopwise
# /search/si/1/Restaurants/Toronto+ON
# /search/si/1/Dentists/Toronto+ON
# /search/si/1/Medical+Clinics/Toronto+ON
# /search/si/1/Car+Repair/Toronto+ON
# /search/si/1/Grocery+Stores/Toronto+ON
# #
# javascript:void(0)
# /search/si-rat/1/Grocery+Stores/Toronto+ON
# /search/si-rev/1/Grocery+Stores/Toronto+ON
# /search/si-alph/1/Grocery+Stores/Toronto+ON
# /search/si-recrev/1/Grocery+Stores/Toronto+ON
# javascript:void(0)
# /search/si-isOnlineShopping/1/Grocery+Stores/Toronto+ON
# #
# /search/si/1/Grocery+Stores/Toronto+ON/ftr-1706-Restaurant+With+Terrace
# /search/si/1/Grocery+Stores/Toronto+ON/ftr-1729-Restaurant+With+Wifi+Internet
# javascript:void(0);
# #
# /search/si-open/1/Grocery+Stores/Toronto+ON
# /search/si-open24Hours/1/Grocery+Stores/Toronto+ON
# #
# /search/si/1/Grocery+Stores/Toronto+ON/rcn-5859039-Downtown-Toronto
# /search/si/1/Grocery+Stores/Toronto+ON/rcn-12808758-East-End
# ...

# %%
anchors = soup.find_all('a')
all_links = set()

for link in anchors:
        if(link.get('href') !='#'):
            link_text = 'https://www.cenitpro.in/resources/free-business-listing-sites-india/' + link.get('href')
            all_links.add(link)
            print(link_text)
# Out:
# https://www.cenitpro.in/resources/free-business-listing-sites-india//
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2053a0097c1b> in <module>
#       4 for link in anchors:
#       5         if(link.get('href') !='#'):
# ----> 6             link_text = 'https://www.cenitpro.in/resources/free-business-listing-sites-india/' + link.get('href')
#       7             all_links.add(link)
#       8             print(link_text)
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
url2 = 'https://www.youtube.com/watch?v=uufDGjTuq34'
r = requests.get(url)
htmlcontent = r.content
print(htmlcontent)
soup = BeautifulSoup(htmlcontent,'html.parser')
# Out:
# b'<!DOCTYPE HTML>\n<html xmlns:fb="http://ogp.me/ns/fb#" xmlns="http://www.w3.org/1999/xhtml" lang="en-CA" xml:lang="en-CA" class="no-js critical-off " >\n<head>\n\n<script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"XAQDWVVXGwsFVlVQBgk=",licenseKey:"d901b4dcbe",applicationID:"8524218"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <!--==========include css links==========-->
#    <!-- Owl Stylesheets -->
#    <link data-minify="1" href="https://www.cenitpro.in/wp-content/cache/min/1/wp-content/themes/cenitpro/owl/owl.carousel-67711b1a80778a1cbf4c7739fbcb200d.css" rel="stylesheet"/>
#    <link data-minify="1" href="https://www.cenitpro.in/wp-content/cache/min/1/wp-content/themes/cenitpro/owl/custom-owl-a052a126abfb211b2d544ea973dc2047.css" rel="stylesheet"/>
#    <!-- Owl Stylesheets -->
#    <!-- Animate Stylesheets -->
#    <link data-minify="1" href="https://www.cenitpro.in/wp-content/cache/min/1/wp-content/themes/cenitpro/css/animate-06865d1c95c2779d424de4a3f4b9734c.css" rel="stylesheet" type="text/css"/>
#    <!-- Animate Stylesheets -->
#    <!-- icon fonts Stylesheets -->
# ...

# %%
print(soup.div.text)
# Out:
#  Career
#  8100-550-550
#  mail@cenitpro.com

# %%
match = soup.find('div',class_='container')

# %%
print(match)
# Out:
# <div class="container">
# <div class="row">
# <div class="top-bar-inner">
# <ul class="top-bar-list">
# <li><a href="https://www.cenitpro.in/jobs/"><i class="icon-font icon-suitcase"></i> Career</a></li>
# <li><a href="tel:+918100550550"><i class="icon-font icon-phone-call"></i> 8100-550-550</a></li>
# <li><a href="mailto:mail@cenitpro.com"><i class="icon-font icon-envelope"></i> mail@cenitpro.com</a></li>
# </ul>
# </div>
# </div>
# </div>

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

# %%
url = 'https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href'
r = requests.get(url)
html = r.content

# %%
soup = BeautifulSoup(html)

# %%
link = soup.find_all('a', href=True)

# %%
links = []
for l in link:
    if(l != '#'):
        if(l['href'][0]=='h' or l['href'][0]=='w'):
            links.append(l['href'])

# %%
urls = links
for i in urls:
    print(i)
# Out:
# https://stackoverflow.com
# https://stackoverflow.com/talent
# https://stackoverflow.com/advertising
# https://stackoverflow.com/users/login?ssrc=head&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f5815747%2fbeautifulsoup-getting-href
# https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent
# https://stackoverflow.com
# https://stackoverflow.com
# https://stackoverflow.com/help
# https://chat.stackoverflow.com/?tab=site&host=stackoverflow.com
# https://meta.stackoverflow.com
# https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent
# https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f5815747%2fbeautifulsoup-getting-href
# https://stackexchange.com/sites
# https://stackoverflow.blog
# https://stackoverflow.com/teams
# https://stackoverflow.com/teams
# http://www.crummy.com/software/BeautifulSoup/documentation.html
# ...

# %%
domain = []
for u in urls:
    parsed_uri = urlparse(u)
    result = '{uri.netloc}'.format(uri=parsed_uri)
    domain.append(result)

# %%
domain = set(domain)
final_domains =  []
for d in domain:
    final_domains.append(d)

# %%
for d in final_domains:
    print(d)
# Out:
# sharepoint.stackexchange.com
# worldbuilding.stackexchange.com
# outdoors.stackexchange.com
# www.crummy.com
# bitcoin.stackexchange.com
# gis.stackexchange.com
# poker.stackexchange.com
# android.stackexchange.com
# mathoverflow.net
# mathematica.stackexchange.com
# api.stackexchange.com
# ethereum.stackexchange.com
# fitness.stackexchange.com
# travel.stackexchange.com
# english.stackexchange.com
# academia.stackexchange.com
# biology.stackexchange.com
# law.stackexchange.com
# emacs.stackexchange.com
# anime.stackexchange.com
# christianity.stackexchange.com
# physics.stackexchange.com
# tex.stackexchange.com
# french.stackexchange.com
# russian.stackexchange.com
# es.stackoverflow.com
# magento.stackexchange.com
# graphicdesign.stackexchange.com
# wordpress.stackexchange.com
# history.stackexchange.com
# meta.stackexchange.com
# boardgames.stackexchange.com
# www.instagram.com
# meta.stackoverflow.com
# dsp.stackexchange.com
# webapps.stackexchange.com
# ux.stackexchange.com
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

url = 'https://api.github.com/search/users?q=type:org'

# %%
parsed_uri = urlparse(url)

# %%
parsed_uri
# Out:
# ParseResult(scheme='https', netloc='api.github.com', path='/search/users', params='', query='q=type:org', fragment='')

# %%
l = [2,1,34,22,43,21]

# %%
sorted(l,)
# Out:
# [43, 34, 22, 21, 2, 1]

# %%
# Python program to illustrate 
# *args for variable number of arguments 
def myFun(*argv):
    for arg in argv: 
        print (arg) 
myFun(1,2,3,4)
# Out:
# 1
# 2
# 3
# 4

# %%
# Python program to illustrate 
# *kargs for variable number of keyword arguments 

def myFun(**kwargs): 
    for key, value in kwargs.items(): 
        print (key, value) 

# Driver code 
myFun(first ='Geeks', mid ='for', last='Geeks')
# Out:
# first Geeks
# mid for
# last Geeks

# %%
from urllib.parse import urlparse
url = 'https://www.amazon.in/s?k=mobile+phones&rh=n%3A1389401031&ref=nb_sb_noss'

# %%
urlp = urlparse(url)

# %%
am = urlp.netloc

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader

# %%
# import PdfFileWriter and PdfFileReader 
# class from PyPDF2 library 
from PyPDF2 import PdfFileWriter, PdfFileReader 

# create a PdfFileWriter object 
out = PdfFileWriter() 

# Open our PDF file with the PdfFileReader 
file = PdfFileReader("anand.pdf") 

# Get number of pages in original file 
num = file.numPages 

# Iterate through every page of the original 
# file and add it to our new file. 
for idx in range(num): 
	
	# Get the page at index idx 
	page = file.getPage(idx) 
	
	# Add it to the output file 
	out.addPage(page) 


# Create a variable password and store 
# our password in it. 
password = "pass"

# Encrypt the new file with the entered password 
out.encrypt(password) 

# Open a new file "myfile_encrypted.pdf" 
with open("myfile_encrypted.pdf", "wb") as f: 
	
	# Write our encrypted PDF to this file 
	out.write(f)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-cf92d5f3f4a5> in <module>
# ----> 1 for i in file:
#       2     print(i)
#
# TypeError: 'PdfFileReader' object is not iterable

# %%
import json,urllib.request
data = urllib.request.urlopen("https://api.github.com/search/users?q=type:org").read()
output = json.loads(data)

# %%
output['items']
# Out:
# [{'login': 'piLights',
#   'id': 14963784,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0OTYzNzg0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/14963784?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/piLights',
#   'html_url': 'https://github.com/piLights',
#   'followers_url': 'https://api.github.com/users/piLights/followers',
#   'following_url': 'https://api.github.com/users/piLights/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/piLights/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/piLights/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/piLights/subscriptions',
#   'organizations_url': 'https://api.github.com/users/piLights/orgs',
#   'repos_url': 'https://api.github.com/users/piLights/repos',
#   'events_url': 'https://api.github.com/users/piLights/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/piLights/received_events',
# ...

# %%
output['items'][2]
# Out:
# {'login': 'AlamoAreaBSA',
#  'id': 14964615,
#  'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0OTY0NjE1',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/14964615?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/AlamoAreaBSA',
#  'html_url': 'https://github.com/AlamoAreaBSA',
#  'followers_url': 'https://api.github.com/users/AlamoAreaBSA/followers',
#  'following_url': 'https://api.github.com/users/AlamoAreaBSA/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/AlamoAreaBSA/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/AlamoAreaBSA/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/AlamoAreaBSA/subscriptions',
#  'organizations_url': 'https://api.github.com/users/AlamoAreaBSA/orgs',
#  'repos_url': 'https://api.github.com/users/AlamoAreaBSA/repos',
#  'events_url': 'https://api.github.com/users/AlamoAreaBSA/events{/privacy}',
# ...

# %%
dic = output['items'][0]

# %%
dic["url"]
# Out:
# 'https://api.github.com/users/piLights'

# %%
u = urllib.request.urlopen("https://api.github.com/search/users?q=type:org").read()

# %%
ou = json.loads(u)

# %%
ou['i']
# Out:
# {'total_count': 3738653,
#  'incomplete_results': False,
#  'items': [{'login': 'piLights',
#    'id': 14963784,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0OTYzNzg0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14963784?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/piLights',
#    'html_url': 'https://github.com/piLights',
#    'followers_url': 'https://api.github.com/users/piLights/followers',
#    'following_url': 'https://api.github.com/users/piLights/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/piLights/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/piLights/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/piLights/subscriptions',
#    'organizations_url': 'https://api.github.com/users/piLights/orgs',
#    'repos_url': 'https://api.github.com/users/piLights/repos',
#    'events_url': 'https://api.github.com/users/piLights/events{/privacy}',
# ...
