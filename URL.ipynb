# %%
import urllib
import requests
from urllib.parse import urlparse

# %%
url = 'https://www.amazon.in/s?k=phone&ref=nb_sb_noss_2'

# %%
u = urlparse(url)

# %%
u
# Out:
# ParseResult(scheme='https', netloc='www.amazon.in', path='/s', params='', query='k=phone&ref=nb_sb_noss_2', fragment='')

# %%
u.netloc
# Out:
# 'www.amazon.in'

# %%
def simpleGeneratorFun(): 
    yield 1
    yield 2
    yield 3

    # Driver code to check above generator function 
for value in simpleGeneratorFun():  
    print(value)
# Out:
# 1
# 2
# 3

# %%
from urllib.parse import urljoin
urljoin('http://www.cwi.nl/%7Eguido/Python.html', 'FAQ.html')
# Out:
# 'http://www.cwi.nl/%7Eguido/FAQ.html'

# %%
url = "http://www.example.com/site/section1/VAR1/VAR2"
url.split("/")[-2:]
# Out:
# ['VAR1', 'VAR2']

# %%
httpr = urllib.request.urlopen('https://oxosolutions.com/')

# %%
hmtl = httpr.read()

# %%
from bs4 import BeautifulSoup
soup =
# Out:
# b'<!doctype html>\n<html lang="en-US">\n<head>\n\t\t<meta charset="UTF-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t<meta name="description" content="OXO Solutions\xc2\xae Offers You Best Suited IT Services in Punjab - Easy Web Plans. We are one of the leading companies in Punjab. We Design unique, creative, professional, and cost-effective websites for small, medium, and large enterprises." />\n\t<meta name="keywords" content="Web Designer in Punjab | Web Designing in Punjab | OXO Solutions" />\n\n\t<meta property="og:title" content="Home" />\n\t<meta property="og:description" content="OXO Solutions is the fastest growing IT solutions provider company, offering all kinds of web development, digital marketing, business automation, and other IT Solutions." />\n\t<meta property="og:url" content="https://oxosolutions.com/" />\n\t<meta property="og:site_name" content="OXO Solutions\xc2\xae" />\n\t<meta property="og:image" content="https://oxosolutions.com/wp-content/uploads/2019/03/oxosolutions-logo-website.png" />\n\n\t<meta name="twitter:title" content="Home" />\n\t<meta name="twitter:description" content="OXO Solutions is the fastest growing IT solutions provider company, offering all kinds of web development, digital marketing, business automation, and other IT Solutions." />\n\t<meta name="twitter:url" content="https://oxosolutions.com/" />\n\t<meta name="twitter:site" content="OXO Solutions\xc2\xae" />\n\t<meta name="twitter:image" content="https://oxosolutions.com/wp-content/uploads/2019/03/oxosolutions-logo-website.png" />\n\n\t<meta name="theme-color" content="#168dc5" />\n\t<link rel="profile" href="http://gmpg.org/xfn/11" />\n\n\t\n\t<link rel="dns-prefetch" href="https://cdn.darlic.com" />\n\t<link href="https://cdn.darlic.com/wp-content/themes/aione/assets/css/core.min.css" rel="stylesheet" media="all">\t\n\t\n\t\n\t<!-- Headstart -->\n\t<!-- Manifest added by SuperPWA - Progressive Web Apps Plugin For WordPress -->\n<link rel="manifest" href="/superpwa-manifest.json">\n<meta name="theme-color" content="#168dc5">\n<!-- / SuperPWA.com -->\n<title>Web Designer in Punjab | Web Designing in Punjab | OXO Solutions &#8211; Developing the .com Trend&#8230;</title>\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="OXO Solutions\xc2\xae &raquo; Feed" href="https://oxosolutions.com/feed/" />\n<link rel="alternate" type="application/rss+xml" title="OXO Solutions\xc2\xae &raquo; Comments Feed" href="https://oxosolutions.com/comments/feed/" />\n<link rel=\'stylesheet\' id=\'redux-google-fonts-theme_options-css\'  href=\'https://fonts.googleapis.com/css?family=Open+Sans%3A300%2C400%2C600%2C700%2C800%2C300italic%2C400italic%2C600italic%2C700italic%2C800italic&#038;ver=1607417564\' media=\'all\' />\n<link rel="https://api.w.org/" href="https://oxosolutions.com/wp-json/" /><link rel="alternate" type="application/json" href="https://oxosolutions.com/wp-json/wp/v2/pages/11" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://oxosolutions.com/xmlrpc.php?rsd" />\n<link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://oxosolutions.com/wp-includes/wlwmanifest.xml" /> \n<meta name="generator" content="WordPress 5.6.1" />\n<link rel="canonical" href="https://oxosolutions.com/" />\n<link rel=\'shortlink\' href=\'https://oxosolutions.com/\' />\n<link rel="alternate" type="application/json+oembed" href="https://oxosolutions.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Foxosolutions.com%2F" />\n<link rel="alternate" type="text/xml+oembed" href="https://oxosolutions.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Foxosolutions.com%2F&#038;format=xml" />\n<script type="text/javascript">\n\t           \tvar ajaxurl = "https://oxosolutions.com/wp-admin/admin-ajax.php";\n         \t</script><link rel="icon" href="https://oxosolutions.com/wp-content/uploads/ ...
